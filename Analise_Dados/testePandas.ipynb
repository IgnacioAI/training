# %%
import pandas as pd

# %%
#leitura de dados
#ficar esperto com as barras invertidas no direcionamento do path - é padrão Linux -
df = pd.read_csv("C:/Users/Forasteiro/Desktop/Python_Estudos/Python_Bootcamp/projetoPython/Analise_Dados/temperature.csv")
df
# Out:
#          date  temperatura classification
# 0  2020-01-01         29.1         quente
# 1  2020-02-01         31.2   muito quente
# 2  2020-03-01         28.5         quente
# 3  2020-04-01         28.0         quente
# 4  2020-05-01         24.0    confortavel
# 5  2020-06-01         20.0           frio

# %%
excel_file = pd.ExcelFile("C:/Users/Forasteiro/Desktop/Python_Estudos/Python_Bootcamp/projetoPython/Analise_Dados/temperature.xlsx")
type(excel_file)

# %%
#leitura de arquivo vindo do excel, o separador por já está "." na primeira aba
df2 = pd.read_excel(excel_file,sheet_name='Sheet1')
df2

# %%
#leitura de arquivo vindo do excel, o separador está em "," na segunda aba
df3 = pd.read_excel(excel_file, sheet_name='Sheet2')

df3['temperatura'] = df3['temperatura'].str.replace(',', '.').astype('float')

df3

# %%
df[df['classification'] == 'quente']

# %%
df.loc[df['classification'] == 'quente','temperatura']

# %%
#transformando o tipo de dado de uma coluna; NNUNCA trabalhe com objetos onde eles não devem estar inferidos. Observe o resultado da função a seguir. Modifique na celula seguinte
df.dtypes
# Out:
# date               object
# temperatura       float64
# classification     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date              datetime64[ns]
# temperatura              float64
# classification            object
# dtype: object

# %%
#setando nosso index
df = df.set_index('date')

# %%
#executando indexações booleanas por tempo e amplitude
#df[df['temperatura'] >= 25]
#até de Março
#df[df.index <= '2020-03-01']
#considerando datetime até Março e "slice" na coluna
#df.loc[df.index <= '2020-03-01',['classification']]
#considerando datetime até Março e "slice" na ultima coluna
df.iloc[df.index <= '2020-03-01',[-1]]

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.plot(figsize=(10,5), grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.plot(style='-o',figsize=(10,5), grid=True);
#df.plot(style='--',figsize=(10,5), grid=True)
#df.plot(style='-',figsize=(10,5), grid=True)

# %%
#df.plot(style='-o',linewidth=2.5 ,figsize=(10,5), grid=True)
df.plot(style='o',linewidth=2.5 ,color='red', figsize=(10,5), grid=True)
#df.plot(style='- .',linewidth=2.5 ,figsize=(10,5), grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['classification'].value_counts().plot.bar(figsize=(10,5), rot=0)
# Out:
# <AxesSubplot:>

# %%
df['classification'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='classification'>

# %%
#agrupando por valores únicos de uma ou mais colunas
df.groupby(by='classification')

# %%
#agrupamento por valores unicos e media
df.groupby(by='classification').mean()

# %%
#agrupamneto por valores unicos e soma total
df.groupby('classification').sum()
